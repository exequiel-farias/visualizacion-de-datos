# %% [markdown]
# # Importando base de datos

# %%
import pandas as pd

# %%
pd.read_csv('credit_card.csv')
# Out:
#       LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE  \
# 0          6022              Yes       2.University  Married   24
# 1         36132              Yes       2.University   Single   26
# 2         27099              Yes       2.University   Single   34
# 3         15055              Yes       2.University  Married   37
# 4        150550               No  3.Graduate School   Single   29
# ...         ...              ...                ...      ...  ...
# 1495      54198              Yes  3.Graduate School   Single   27
# 1496      45165               No       2.University  Married   55
# 1497      78286               No  3.Graduate School   Single   34
# 1498       6022               No       2.University  Married   44
# 1499     183671               No  3.Graduate School   Single   31
#
#          BILL_AMT     PAY_AMT  DEFAULT
# 0        934.0122      0.0000        1
# 1        519.3975      0.0000        1
# 2       4223.5297    457.0698        0
# ...

# %%
datos = pd.read_csv('credit_card.csv')

# %%
datos.head()
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# 4  16560.5000        0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %% [markdown]
# # Traduciendo variables

# %%
datos.columns
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
dic_columnas = {
    'LIMIT_BAL': 'limite',
    'CHECKING_ACCOUNT': 'cuenta_corriente', 
    'EDUCATION': 'escolaridad', 
    'MARRIAGE': 'estado_civil', 
    'AGE': 'edad',
    'BILL_AMT': 'valor_factura', 
    'PAY_AMT': 'valor_pago', 
    'DEFAULT': 'moroso'
}

# %%
tarjetas = datos.rename(columns = dic_columnas)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.cuenta_corriente.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dic_cuenta = {
    'Yes': 'Si',
    'No': 'No'
}

# %%
tarjetas.cuenta_corriente.map(dic_cuenta)
# Out:
# 0       Si
# 1       Si
# 2       Si
# 3       Si
# 4       No
#         ..
# 1495    Si
# 1496    No
# 1497    No
# 1498    No
# 1499    No
# Name: cuenta_corriente, Length: 1500, dtype: object

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.cuenta_corriente = tarjetas.cuenta_corriente.map(dic_cuenta)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022               Si       2.University      Married    24
# 1   36132               Si       2.University       Single    26
# 2   27099               Si       2.University       Single    34
# 3   15055               Si       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.escolaridad.unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
dic_escolaridad = {
    '2.University': '2.Universidad', 
    '3.Graduate School': '3.Pos-graduación', 
    '1.High School': '1.Colegio'
}

# %%
tarjetas.escolaridad = tarjetas.escolaridad.map(dic_escolaridad)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad      Married    24
# 1   36132               Si     2.Universidad       Single    26
# 2   27099               Si     2.Universidad       Single    34
# 3   15055               Si     2.Universidad      Married    37
# 4  150550               No  3.Pos-graduación       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.estado_civil.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
dic_estado_civil = {
    'Married': 'Casado/a',
    'Single': 'Soltero/a'
}

# %%
tarjetas.estado_civil = tarjetas.estado_civil.map(dic_estado_civil)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %% [markdown]
# # Importando Seaborn

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.11.2
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@gmail.com
# License: BSD (3-clause)
# Location: /usr/local/lib/python3.8/dist-packages
# Requires: matplotlib, numpy, pandas, scipy
# Required-by: missingno

# %%
#filas y columnas
tarjetas.shape
# Out:
# (1500, 8)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %% [markdown]
# # Analisis 1

# %%
#funcion deprecada
sns.distplot(tarjetas['limite'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#nueva funcion que no tira el warning
sns.displot(data=tarjetas,x='limite')

# %%
#para sacar el texto que aparece en el grafico se usa ; a lo ultimo
#Grafico de distribucion analizando la escolaridad
sns.displot(data=tarjetas,x='limite', hue = 'escolaridad');

# %% [markdown]
# # Analisis 2

# %%
#iu: indice de uso, es el porcentaje que una persona usa de su limite
tarjetas['iu'] = tarjetas['valor_factura'] / tarjetas['limite']

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
sns.displot(data = tarjetas, x = 'iu');

# %% [markdown]
# Hay un publico significativo que usa poco del limite que tienen disponible

# %% [markdown]
# # Estilos y colores

# %%
#Dando estilo al grafico
sns.set_style('whitegrid')

# %%
sns.displot(data=tarjetas,x='limite', hue = 'escolaridad');

# %%
#Otro estilo de grafico
sns.set_style('darkgrid')
#Para cambiar el color del grafico se usa 'palette'
sns.displot(data=tarjetas,x='limite', hue = 'escolaridad', palette = 'inferno');

# %% [markdown]
# Para ver todas las opciones de colores disponibles: https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %% [markdown]
# # Analisis de variables categoricas

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
#Este gráfico nos permite contar el número de vezes que una opción se repite en una variable
sns.countplot(x='cuenta_corriente', data = tarjetas);

# %%
#moroso es 1, no moroso es 0
#con el parámetro hue de esta función podemos traer otra variable para nuestro gráfico y analizarla al lado de nuestra variable x
sns.countplot(x='cuenta_corriente', data = tarjetas, hue = 'moroso');

# %%
#Sera que las personas que son casadas tienen mas limites que las personas que son solteras?
#Este gráfico nos permite comparar una variable categórica (eje x) y una variable numérica (eje y).
#Podemos ver cómo está distribuida nuestra variable categórica en relación con nuestra variable numérica:
sns.catplot(x='estado_civil',y='limite',data=tarjetas);

# %% [markdown]
# No hay alguna diferencia significativa

# %%
#Analisis de grupos casados y solteros con sus limites y morosidad
#usamos el parámetro dodge para que se muestran columnas diferentes para esta variable y no se agrupen solamente en una columna
sns.catplot(x='estado_civil',y='limite',data=tarjetas, hue='moroso',dodge=True);

# %%
#Sera que el nivel de escolaridad tiene alguna influencia con lo que gastan?
#Es un gráfico bastante parecido al catplot solo que en este gráfico los puntos de nuestra variable no se sobreponen
sns.swarmplot(x='escolaridad', y='iu',data=tarjetas);
#Un porcentaje de la base de datos no pudo ser mostrada porque iba a cruzarse una columna con otra
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 22.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 32.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 7.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x='escolaridad', y='iu', data=tarjetas);

# %%
sns.boxplot(x='escolaridad', y='iu', data=tarjetas, hue='moroso');
#Comencemos viendo el rectángulo, la línea inferior es el percentil 25%, la línea superior es el percentil 75% y 
#la línea que cruza el rectángulo es el percentil 50% o la mediana.
#Hay dos líneas perpendiculares que van más allá de las medidas del rectángulo, el punto inferior de la línea que va hacia abajo 
#es el punto mínimo en nuestra variable, y el punto máximo de la línea que va hacia arriba es el punto máximo.
#Si hay puntos más allá de estos dos líneas, estos son considerados outliers.

# %%
sns.violinplot(x='escolaridad',y='iu',data=tarjetas, hue = 'moroso');
#El punto blanco representa la media

# %% [markdown]
# Sera que las personas de mayor edad tienen un limite mas alto?

# %%
tarjetas.edad.unique()
#Al tener mucho valores, el grafico no quedaria bien si usamos todos los valores, conviene usar rango de valores
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72])

# %%
#Lista con los valores que serán nuestro punto de corte
bins = [20,30,40,50,100]
#Nombres de rangos
nombres = ['20-30','30-40','40-50','50+']

tarjetas['rango_edad'] = pd.cut(tarjetas['edad'],bins, labels = nombres)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu rango-edad rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30      20-30
# 1       519.3975      0.0000       1  0.014375      20-30      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30      20-30

# %%
#Respondiendo a la pregunta anterior
sns.boxplot(x='rango_edad', y='limite', data=tarjetas);

# %% [markdown]
# Las personas que tienen más limite son las que están en el rango de 30-40 años

# %% [markdown]
# # Analisis de variables numericas

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu rango-edad rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30      20-30
# 1       519.3975      0.0000       1  0.014375      20-30      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30      20-30

# %%
sns.displot(data=tarjetas, x='limite', hue='escolaridad');

# %%
#Para crear un grafico para cada una de las opciones de escolaridad se hace:
sns.displot(data=tarjetas, x='limite', col='escolaridad');

# %%
#Funcion densidad
sns.displot(data=tarjetas, x='limite', col='escolaridad', kind='kde', hue='rango_edad');

# %% [markdown]
# Dispersión

# %%
#El gráfico de dispersión nos muestra cómo se relacionan dos variables numéricas y si existe alguna tendencia o correlación entre ellas
sns.scatterplot(x='iu',y='valor_factura',data=tarjetas, hue='cuenta_corriente');

# %%
sns.lmplot(x='iu',y='valor_factura',data=tarjetas);
#Muestra una linea de regresion que mejor se ajuste a la relación entre las dos variables

# %% [markdown]
# # Test de hipotesis

# %%
sns.lmplot(x='iu',y='valor_factura',data=tarjetas, col='moroso');

# %%
from scipy.stats import ranksums

# %% [markdown]
# Ahora realizaremos un test de hipótesis con la variable moroso, para conocer si estos dos grupos (moroso y no moroso) son estadísticamente diferentes o no.

# %% [markdown]
# H<sup>null<sup>
#
# La distribución de los grupos moroso y no moroso es la misma

# %% [markdown]
# H<sup>alt<sup>
#
# La distribución de los grupos moroso y no moroso no es la misma

# %%
#Crear grupos moroso y no moroso
moroso = tarjetas.query("moroso == 1").valor_factura
no_moroso = tarjetas.query("moroso == 0").valor_factura

# %%
moroso
# Out:
# 0         934.0122
# 1         519.3975
# 38      10891.0881
# 45        330.6078
# 47       7316.7300
#            ...
# 1448     1619.0147
# 1472    17048.2820
# 1475     4402.0820
# 1478     1851.1628
# 1495      295.0780
# Name: valor_factura, Length: 117, dtype: float64

# %%
no_moroso
# Out:
# 2         4223.5297
# 3        14522.9563
# 4       124060.1253
# 5          114.4180
# 6         4244.3056
#            ...
# 1494     32698.2556
# 1496     23637.8555
# 1497       962.9178
# 1498       864.7592
# 1499     97022.8508
# Name: valor_factura, Length: 1383, dtype: float64

# %%
#Vemos si estos dos grupos si la diferencia en la distribucion es significativa
resultado = ranksums(moroso, no_moroso)

# %%
print("El p.value de nuestro test es {}".format(resultado.pvalue))
# Out:
# El p.value de nuestro test es 0.010391243081223555

# %% [markdown]
# Podemos ver que el pvalue está debajo del 5% por lo que sirve para aceptar la hipotesis alternativa. Entonces podemos decir la distribución de los grupos moroso y no moroso no es la misma

# %% [markdown]
# # JointPlot

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu rango-edad rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30      20-30
# 1       519.3975      0.0000       1  0.014375      20-30      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30      20-30

# %%
sns.jointplot(x='edad',y='limite',data=tarjetas);
#Ademas del grafico de dispersion muestra el histograma para cada variable
#Podemos definir el tipo de gráfico que queremos mostrar con el parámetro kind, las opciones que éste parámetro nos permite son:
#(“scatter”, “kde”, “hist”, “hex”, “reg”, “resid” )

# %%
#Se puede modificar el estilo del grafico
sns.jointplot(x='edad',y='limite',data=tarjetas, kind='kde');
#Cuando las lineas estan mas juntas, la concentracion es mayor
#Y tenemos la funcion densidad para cada variable

# %%
sns.jointplot(x='edad',y='limite',data=tarjetas, kind='hex');
#Donde esta mas oscuro, la concentracion es mayor

# %%
sns.jointplot(x='edad',y='limite',data=tarjetas, kind='kde', hue = 'moroso');

# %% [markdown]
# # Pairplot

# %%
tarjetas.describe()
# Out:
#               limite         edad  valor_factura    valor_pago       moroso  \
# count    1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean    51221.943333    35.212667   15459.869900   1984.869266     0.078000
# std     39424.407462     9.274955   20722.582831   5296.771686     0.268261
# min      3011.000000    21.000000      27.701200      0.000000     0.000000
# 25%     18066.000000    28.000000    2035.586550    407.011925     0.000000
# 50%     42154.000000    33.500000    7701.385250    759.374200     0.000000
# 75%     72264.000000    41.000000   20671.568850   1705.279850     0.000000
# max    210770.000000    75.000000  141792.506500  97022.850800     1.000000
#
#                 iu
# count  1500.000000
# mean      0.388237
# std       0.341923
# min       0.000188
# 25%       0.049209
# 50%       0.308976
# 75%       0.704090
# max       0.998010

# %%
#Función que creará una cuadrícula de gráficos de forma que cada variable numérica será 
#analizada con las demás variables numéricas de la base de datos y con ella misma.
sns.pairplot(data=tarjetas);

# %%
sns.pairplot(data=tarjetas, hue = 'escolaridad', palette = 'cividis');
